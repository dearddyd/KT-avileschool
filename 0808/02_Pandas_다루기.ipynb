# %% [markdown]
# # Pandas 2 : 집계, 결합

# %% [markdown]
# ## 환경준비 + 데이터 로드

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * 데이터 로딩

# %%
# 데이터1 : 보스톤 타운별 집값
boston = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/boston2.csv")
boston.head()
# Out:
#       crim  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv  zn2
# 0  396.90   4.98  24.0    1
# 1  396.90   9.14  21.6    0
# 2  392.83   4.03  34.7    0
# 3  394.63   2.94  33.4    0
# 4  396.90   5.33  36.2    0

# %%
# 데이터2 : 타이타닉 승객 생존여부
titanic = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.0.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Dataframe 다루기

# %% [markdown]
# ### 5.1 결합 1 : 조인 join(merge)
#
# - 결합은 나눠어진 데이터셋으로 부터 하나로 모으는 작업입니다.

# %% [markdown]
# * 판다스에서 join은 굉장히 간단합니다.
# * 자동으로 key를 잡아줍니다
# * default로 inner join을 합니다.

# %%
sales = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/sales.csv")
products = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/products.csv")

# %%
sales.head()
# Out:
#    OrderID  Seq   OrderDate ProductID  Qty   Amt CustomerID
# 0      107    2  2016-01-02  p1036481    2  2100    c150417
# 1       69    1  2016-01-02  p1152861    1  1091    c212716
# 2       69    7  2016-01-02  p1013161    1  2600    c212716
# 3       69    8  2016-01-02  p1005771    1  1650    c212716
# 4       69   11  2016-01-02  p1089531    1  2600    c212716

# %%
products.head()
# Out:
#   ProductID ProductName Category SubCategory  CategoryOrd
# 0  p1052661         새우깡       간식          과자            3
# 1  p1054261       고구마스틱       간식          과자            3
# 2  p1097821          짱구       간식          과자            3
# 3  p1097831         감자칩       간식          과자            3
# 4  p1119071        뿌셔뿌셔       간식          과자            3

# %%
pd.merge(sales, products).head() # 공통된 칼럼이 있으면 그 칼럼을 key로 사용
# Out:
#    OrderID  Seq   OrderDate ProductID  Qty    Amt CustomerID ProductName  \
# 0      107    2  2016-01-02  p1036481    2   2100    c150417         순두부
# 1      137    4  2016-01-02  p1036481    2   2100    c280590         순두부
# 2       63   16  2016-01-03  p1036481    1   1050    c037915         순두부
# 3      135    3  2016-01-04  p1036481    3   3150    c100815         순두부
# 4       63   13  2016-01-06  p1036481   10  10500    c048405         순두부
#
#   Category SubCategory  CategoryOrd
# 0      반찬류          두부            1
# 1      반찬류          두부            1
# 2      반찬류          두부            1
# 3      반찬류          두부            1
# 4      반찬류          두부            1

# %% [markdown]
# how 파라미터에 값을 지정하여 outer join을 수행합니다.
#
# how='inner'
#
# ==> left, right, outer

# %%
pd.merge(sales, products, how='left').head()
# Out:
#    OrderID  Seq   OrderDate ProductID  Qty   Amt CustomerID ProductName  \
# 0      107    2  2016-01-02  p1036481    2  2100    c150417         순두부
# 1       69    1  2016-01-02  p1152861    1  1091    c212716     포토아이스크림
# 2       69    7  2016-01-02  p1013161    1  2600    c212716       느타리버섯
# 3       69    8  2016-01-02  p1005771    1  1650    c212716        두부_소
# 4       69   11  2016-01-02  p1089531    1  2600    c212716         감자칩
#
#   Category SubCategory  CategoryOrd
# 0      반찬류          두부            1
# 1      유제품       아이스크림            4
# 2       채소          버섯            5
# 3      반찬류          두부            1
# 4       채소        뿌리채소            5

# %% [markdown]
# ### 실습 6 : Join(Merge) + groupby

# %% [markdown]
# * Q1. sales와 products를 ProductID 기준으로 merge하여 새로운 데이터프레임으로 저장합니다.

# %%
data = pd.merge(sales, products)
display(data2)
# Out:
#   Category       Amt
# 0       간식  12920570
# 1       과일  49789339
# 2      반찬류  32204820
# 3      유제품  45261956
# 4       채소  54822783

# %% [markdown]
# * Q2. Category별 총 매출액(amt)

# %%
pd.DataFrame(data.groupby([data2.Category])['Amt'].sum())
# Out:
#             Amt
# Category
# 간식         2100
# 과일         2100
# 반찬류        1050
# 유제품        3150
# 채소        10500

# %% [markdown]
# * Q3. Category별 총 판매량 (qty)

# %%
data.groupby('Category', as_index = False)['Qty'].sum()
# Out:
#   Category    Qty
# 0       간식  12130
# 1       과일   6786
# 2      반찬류  20210
# 3      유제품  19731
# 4       채소  27859

# %% [markdown]
# * Q4. 전체에서 가장 매출이 높은 상품명 10개 조회

# %%
data.groupby('ProductName', as_index = False)['Amt'].sum().sort_values('Amt', ascending = False).head()
# Out:
#    ProductName       Amt
# 37      우유1000  18129067
# 23        사과_소  14078818
# 9         딸기_대  11011541
# 7         두부_대  10119037
# 10        딸기_소   7517664

# %% [markdown]
# ### 5.3 결합 2 : 붙이기  concat( )
#
# * 방금 전 실습에서 2,3번의 결과를 각각 dataframe으로 저장하시오.

# %%
data2 = data.groupby('Category', as_index=False)['Amt'].sum()
data3 = data.groupby('Category', as_index=False)['Qty'].sum()

# %% [markdown]
# * 위 아래로 붙이기

# %%
pd.concat([data2, data3])
# Out:
#   Category         Amt      Qty
# 0       간식  12920570.0      NaN
# 1       과일  49789339.0      NaN
# 2      반찬류  32204820.0      NaN
# 3      유제품  45261956.0      NaN
# 4       채소  54822783.0      NaN
# 0       간식         NaN  12130.0
# 1       과일         NaN   6786.0
# 2      반찬류         NaN  20210.0
# 3      유제품         NaN  19731.0
# 4       채소         NaN  27859.0

# %% [markdown]
# * 옆으로 붙이기

# %%
pd.concat([data2, data3], axis=1)
# Out:
#   Category       Amt Category    Qty
# 0       간식  12920570       간식  12130
# 1       과일  49789339       과일   6786
# 2      반찬류  32204820      반찬류  20210
# 3      유제품  45261956      유제품  19731
# 4       채소  54822783       채소  27859

# %% [markdown]
# ### 실습 7. concat( )

# %% [markdown]
# * Q1. 2016년 1월 데이터를 가진 데이터프레임과 2017년 1월 데이터를 가진 데이터프레임을 만드시오.

# %%
_2016 = sales.loc[(sales['OrderDate'].isin('2016-01'))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Coding\KT_CODING_1\0805\KT-avileschool\0808\02_Pandas_다루기.ipynb 셀 35 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Coding/KT_CODING_1/0805/KT-avileschool/0808/02_Pandas_%EB%8B%A4%EB%A3%A8%EA%B8%B0.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> _2016 = sales.loc[(sales['OrderDate'].isin('2016-01'))]
#
# File d:\anaconda\lib\site-packages\pandas\core\series.py:5141, in Series.isin(self, values)
#    5068 def isin(self, values) -> Series:
#    5069     """
#    5070     Whether elements in Series are contained in `values`.
#    5071
#    (...)
#    5139     dtype: bool
#    5140     """
# -> 5141     result = algorithms.isin(self._values, values)
#    5142     return self._constructor(result, index=self.index).__finalize__(
#    5143         self, method="isin"
#    5144     )
#
# File d:\anaconda\lib\site-packages\pandas\core\algorithms.py:468, in isin(comps, values)
#     463     raise TypeError(
#     464         "only list-like objects are allowed to be passed "
#     465         f"to isin(), you passed a [{type(comps).__name__}]"
#     466     )
#     467 if not is_list_like(values):
# --> 468     raise TypeError(
#     469         "only list-like objects are allowed to be passed "
#     470         f"to isin(), you passed a [{type(values).__name__}]"
#     471     )
#     473 if not isinstance(values, (ABCIndex, ABCSeries, ABCExtensionArray, np.ndarray)):
#     474     values = _ensure_arraylike(list(values))
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]

# %% [markdown]
# * Q2. Q1에서 만든 데이터프레임을 위, 아래로 붙이시오.

# %% [markdown]
# ### 5.4 추가 : Rolling & Shift
#  - rolling은 주로 시계열 데이터에 대해서 이동평균값을 구하거나, 행을 shift(이동) 시킬 때 주로 사용합니다.
#  - 시계열 데이터 : 행과 행에 시간순서가 있는 데이터(전제 : 시간순으로 정렬 되어 있는 상태)

# %%
import pandas as pd

# %%
stock = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/SK.csv') 
stock.head()

# %% [markdown]
# * stock 데이터프레임에서 Date, Close, Volume 만을 남깁니다.

# %%
# stock.drop으로 칼럼을 삭제할수도 있고, 아래와 같이 특정 칼럼으로 구성된 데이터프레임을 만들수도 있습니다.
stock = stock[['Date', 'Close', 'Volume']]
#stock = stock.loc[:, ['Date', 'Close', 'Volume']]

stock.head()
# Out:
#          Date   Close  Volume
# 0  2015-01-02  8820.0  341169
# 1  2015-01-05  8820.0  484752
# 2  2015-01-06  8600.0  360161
# 3  2015-01-07  8650.0  300467
# 4  2015-01-08  8650.0  490843

# %% [markdown]
# 기준일 포함하여 과거 3일의 평균을 데이터 프레임에 붙여봅시다.

# %%
stock['Close_MA_3'] = stock['Close'].rolling(3).mean()
stock.head(10)
# Out:
#          Date   Close   Volume   Close_MA_3
# 0  2015-01-02  8820.0   341169          NaN
# 1  2015-01-05  8820.0   484752          NaN
# 2  2015-01-06  8600.0   360161  8746.666667
# 3  2015-01-07  8650.0   300467  8690.000000
# 4  2015-01-08  8650.0   490843  8633.333333
# 5  2015-01-09  8700.0   506497  8666.666667
# 6  2015-01-12  8970.0   528617  8773.333333
# 7  2015-01-13  9070.0  1113489  8913.333333
# 8  2015-01-14  8780.0   791802  8940.000000
# 9  2015-01-15  8670.0   440961  8840.000000

# %%
stock['Close_MA_3_lag1'] = stock['Close_MA_3'].shift(1) # shift()안에 숫자를 변경해 보며 기능을 알아보자. default = 1
stock.head(10)
# Out:
#          Date   Close   Volume   Close_MA_3  Close_MA_3_lag1  \
# 0  2015-01-02  8820.0   341169          NaN              NaN
# 1  2015-01-05  8820.0   484752          NaN              NaN
# 2  2015-01-06  8600.0   360161  8746.666667              NaN
# 3  2015-01-07  8650.0   300467  8690.000000      8746.666667
# 4  2015-01-08  8650.0   490843  8633.333333      8690.000000
# 5  2015-01-09  8700.0   506497  8666.666667      8633.333333
# 6  2015-01-12  8970.0   528617  8773.333333      8666.666667
# 7  2015-01-13  9070.0  1113489  8913.333333      8773.333333
# 8  2015-01-14  8780.0   791802  8940.000000      8913.333333
# 9  2015-01-15  8670.0   440961  8840.000000      8940.000000
#
#    Close_MA_3_lag1_2  Close_MA_3(2)
# 0                NaN    8820.000000
# 1                NaN    8820.000000
# 2                NaN    8746.666667
# 3        8746.666667    8690.000000
# 4        8690.000000    8633.333333
# 5        8633.333333    8666.666667
# 6        8666.666667    8773.333333
# 7        8773.333333    8913.333333
# 8        8913.333333    8940.000000
# 9        8940.000000    8840.000000

# %%
# 이동평균(rolling)과 하루 뒤로 미루는(shift) 작업을 한꺼번에 하려면?
stock['Close_MA_3_lag1_2'] = stock['Close'].rolling(3).mean().shift()
stock.head(10)
# Out:
#          Date   Close   Volume   Close_MA_3  Close_MA_3_lag1  \
# 0  2015-01-02  8820.0   341169          NaN              NaN
# 1  2015-01-05  8820.0   484752          NaN              NaN
# 2  2015-01-06  8600.0   360161  8746.666667              NaN
# 3  2015-01-07  8650.0   300467  8690.000000      8746.666667
# 4  2015-01-08  8650.0   490843  8633.333333      8690.000000
# 5  2015-01-09  8700.0   506497  8666.666667      8633.333333
# 6  2015-01-12  8970.0   528617  8773.333333      8666.666667
# 7  2015-01-13  9070.0  1113489  8913.333333      8773.333333
# 8  2015-01-14  8780.0   791802  8940.000000      8913.333333
# 9  2015-01-15  8670.0   440961  8840.000000      8940.000000
#
#    Close_MA_3_lag1_2  Close_MA_3(2)
# 0                NaN    8820.000000
# 1                NaN    8820.000000
# 2                NaN    8746.666667
# 3        8746.666667    8690.000000
# 4        8690.000000    8633.333333
# 5        8633.333333    8666.666667
# 6        8666.666667    8773.333333
# 7        8773.333333    8913.333333
# 8        8913.333333    8940.000000
# 9        8940.000000    8840.000000

# %% [markdown]
# min_periods를 기억하자

# %%
stock['Close_MA_3(2)'] = stock['Close'].rolling(3, min_periods=1).mean()
stock.head()
# Out:
#          Date   Close  Volume   Close_MA_3  Close_MA_3_lag1  \
# 0  2015-01-02  8820.0  341169          NaN              NaN
# 1  2015-01-05  8820.0  484752          NaN              NaN
# 2  2015-01-06  8600.0  360161  8746.666667              NaN
# 3  2015-01-07  8650.0  300467  8690.000000      8746.666667
# 4  2015-01-08  8650.0  490843  8633.333333      8690.000000
#
#    Close_MA_3_lag1_2  Close_MA_3(2)
# 0                NaN    8820.000000
# 1                NaN    8820.000000
# 2                NaN    8746.666667
# 3        8746.666667    8690.000000
# 4        8690.000000    8633.333333

# %% [markdown]
# ### 실습 8 : Rolling & Shift

# %% [markdown]
# * 아래 셀을 실행한 후 진행하시오

# %%
stock = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/sknetworks.csv', sep=',', skipinitialspace=True) 
stock = stock[['Date', 'Close', 'Volume']]
stock.head()
# Out:
#          Date   Close  Volume
# 0  2015-01-02  8820.0  341169
# 1  2015-01-05  8820.0  484752
# 2  2015-01-06  8600.0  360161
# 3  2015-01-07  8650.0  300467
# 4  2015-01-08  8650.0  490843

# %% [markdown]
# * Q1. stock 데이터프레임에 전날 주가 컬럼과 전전날 주가 컬럼을 추가하세요.

# %%
stock['Y_Close'] = stock['Close'].shift(1)
stock['YY_Close'] = stock['Close'].shift(2)
stock.head()
# Out:
#          Date   Close  Volume YesterDay_close  Y_Close  YY_Close
# 0  2015-01-02  8820.0  341169      2015-01-02      NaN       NaN
# 1  2015-01-05  8820.0  484752      2015-01-05   8820.0       NaN
# 2  2015-01-06  8600.0  360161      2015-01-06   8820.0    8820.0
# 3  2015-01-07  8650.0  300467      2015-01-07   8600.0    8820.0
# 4  2015-01-08  8650.0  490843      2015-01-08   8650.0    8600.0

# %% [markdown]
# * Q2. 전전날 대비 전날 주가 증감 컬럼을 추가하세요.

# %%
stock['change'] = stock['Y_Close'] - stock['YY_Close']
stock.head()
# Out:
#          Date   Close  Volume YesterDay_close  Y_Close  YY_Close  Max_3day  \
# 0  2015-01-02  8820.0  341169      2015-01-02      NaN       NaN    8820.0
# 1  2015-01-05  8820.0  484752      2015-01-05   8820.0       NaN    8820.0
# 2  2015-01-06  8600.0  360161      2015-01-06   8820.0    8820.0    8820.0
# 3  2015-01-07  8650.0  300467      2015-01-07   8600.0    8820.0    8820.0
# 4  2015-01-08  8650.0  490843      2015-01-08   8650.0    8600.0    8650.0
#
#    change
# 0     NaN
# 1     NaN
# 2     0.0
# 3  -220.0
# 4    50.0

# %% [markdown]
# * Q3. Q2에서 만든 컬럼의 각 데이터가 양수이면 1, 음수이면 0인 컬럼을 추가하세요.

# %%
bin = [-np.inf, 0,np.inf]
stock['change'] = pd.cut(stock['change'], bins = bin, labels = ['0','1'])
stock.head()
# Out:
#          Date   Close  Volume YesterDay_close  Y_Close  YY_Close  Max_3day  \
# 0  2015-01-02  8820.0  341169      2015-01-02      NaN       NaN    8820.0
# 1  2015-01-05  8820.0  484752      2015-01-05   8820.0       NaN    8820.0
# 2  2015-01-06  8600.0  360161      2015-01-06   8820.0    8820.0    8820.0
# 3  2015-01-07  8650.0  300467      2015-01-07   8600.0    8820.0    8820.0
# 4  2015-01-08  8650.0  490843      2015-01-08   8650.0    8600.0    8650.0
#
#   change  Max_3day_lag  Max_7day_lag  Volum_7day_lag
# 0    NaN           NaN           NaN             NaN
# 1    NaN           NaN           NaN             NaN
# 2      0           NaN           NaN             NaN
# 3      0        8820.0           NaN             NaN
# 4      1        8820.0           NaN             NaN

# %% [markdown]
# * Q4. 3일 이동 최대 주가를 추가하세요.

# %%
stock['Max_3day'] = stock['Close'].rolling(3,min_periods=1).max()
stock.head()
# Out:
#          Date   Close  Volume YesterDay_close  Y_Close  YY_Close  Max_3day  \
# 0  2015-01-02  8820.0  341169      2015-01-02      NaN       NaN    8820.0
# 1  2015-01-05  8820.0  484752      2015-01-05   8820.0       NaN    8820.0
# 2  2015-01-06  8600.0  360161      2015-01-06   8820.0    8820.0    8820.0
# 3  2015-01-07  8650.0  300467      2015-01-07   8600.0    8820.0    8820.0
# 4  2015-01-08  8650.0  490843      2015-01-08   8650.0    8600.0    8650.0
#
#    change
# 0     NaN
# 1     NaN
# 2     0.0
# 3  -220.0
# 4    50.0

# %% [markdown]
# * Q5. 기준일을 포함하지 않은, 과거 3일의 최대 주가를 추가하세요.

# %%
stock['Max_3day_lag'] = stock['Close'].rolling(3).max().shift(1)
stock.head()
# Out:
#          Date   Close  Volume YesterDay_close  Y_Close  YY_Close  Max_3day  \
# 0  2015-01-02  8820.0  341169      2015-01-02      NaN       NaN    8820.0
# 1  2015-01-05  8820.0  484752      2015-01-05   8820.0       NaN    8820.0
# 2  2015-01-06  8600.0  360161      2015-01-06   8820.0    8820.0    8820.0
# 3  2015-01-07  8650.0  300467      2015-01-07   8600.0    8820.0    8820.0
# 4  2015-01-08  8650.0  490843      2015-01-08   8650.0    8600.0    8650.0
#
#    change  Max_3day_lag
# 0     NaN           NaN
# 1     NaN           NaN
# 2     0.0           NaN
# 3  -220.0        8820.0
# 4    50.0        8820.0

# %% [markdown]
# * Q6. 기준일을 포함하지 않은, 과거 7일 평균 거래량을 추가하세요.

# %%
stock['Volum_7day_lag'] = stock['Volume'].rolling(7).mean().shift(1)
stock.head()
# Out:
#          Date   Close  Volume YesterDay_close  Y_Close  YY_Close  Max_3day  \
# 0  2015-01-02  8820.0  341169      2015-01-02      NaN       NaN    8820.0
# 1  2015-01-05  8820.0  484752      2015-01-05   8820.0       NaN    8820.0
# 2  2015-01-06  8600.0  360161      2015-01-06   8820.0    8820.0    8820.0
# 3  2015-01-07  8650.0  300467      2015-01-07   8600.0    8820.0    8820.0
# 4  2015-01-08  8650.0  490843      2015-01-08   8650.0    8600.0    8650.0
#
#    change  Max_3day_lag  Max_7day_lag  Volum_7day_lag
# 0     NaN           NaN           NaN             NaN
# 1     NaN           NaN           NaN             NaN
# 2     0.0           NaN           NaN             NaN
# 3  -220.0        8820.0           NaN             NaN
# 4    50.0        8820.0           NaN             NaN

# %% [markdown]
# * Q7. 기준일을 포함하지 않은 과거 7일 평균 거래량을 추가하되, 최소 1일 데이터만 있어도 평균값이 나오게 만드시오.
